# %%
import pandas as pd

# %%
df_2015 = pd.read_csv('2015_복지_사회참여_문화와여가_소득과소비_노동.csv')
df_2017 = pd.read_csv('2017_복지_사회참여_문화와여가_소득과소비_노동.csv')
df_2019 = pd.read_csv('2019_복지_사회참여_문화와여가_소득과소비_노동.csv')
df_2021 = pd.read_csv('2021_복지_사회참여_문화와여가_소득과소비_노동.csv')
df_2023 = pd.read_csv('2023_복지_사회참여_문화와여가_소득과소비_노동.csv')
df_2017
# Out:
# c:\Users\sanna\miniconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3508: DtypeWarning: Columns (185) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# c:\Users\sanna\miniconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3508: DtypeWarning: Columns (189) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# c:\Users\sanna\miniconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3508: DtypeWarning: Columns (234) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# c:\Users\sanna\miniconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3508: DtypeWarning: Columns (236) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %%
# 데이터프레임들을 딕셔너리로 묶음
years = {
    "2015": df_2015,
    "2017": df_2017,
    "2019": df_2019,
    "2021": df_2021,
    "2023": df_2023
}

# 각 연도별 피쳐 추출
features = {year: df.columns.tolist() for year, df in years.items()}

# 출력
for year, cols in features.items():
    print(f"{year} features:", cols)
# Out:
# 2015 features: ['가구일련번호', '가구원번호', '행정구역시도코드', '만연령', '성별코드', '주관적만족감코드', '가구주관계코드', '교육정도코드', '재학상태코드', '혼인상태코드', '재학학년코드', '장애인복지카드_소유여부', '생활여건변화_전반적생활여건코드', '생활여건변화_보건의료서비스코드', '생활여건변화_사회보장제도코드', '생활여건변화_문화여가생활여건코드', '사회보험료부담인식_건강보험납부여부', '사회보험료부담인식_건강보험부담정도코드', '사회보험료부담인식_국민연금납부여부', '사회보험료부담인식_국민연금부담정도코드', '사회보험료부담인식_고용보험납부여부', '사회보험료부담인식_고용보험부담정도코드', '향후추가대상공공시설_1순위코드', '향후추가대상공공시설_2순위코드', '향후추가대상공공시설_3순위코드', '향후추가대상복지서비스_1순위코드', '향후추가대상복지서비스_2순위코드', '향후추가대상복지서비스_3순위코드', '선호장례방법코드', '사회장애인차별정도코드', '장애인견해코드', '장애인관련시설견해코드', '장애인복지사업견해코드', '우선실시장애인복지사업_1순위코드', '우선실시장애인복지사업_2순위코드', '우선실시장애인복지사업_3순위코드', '노후준비방법_본인노후준비여부', '노후준비방법_주된방법코드', '노후준비방법_부수적방법코드', '노후준비방법_노후미준비사유코드', '노후사회적관심사코드', '노후희망활동코드', '생활비마련방법코드', '생활비마련방법_본인및배우자부담코드', '생활비마련방법_지원자녀및친척동거여부', '현재자녀동거여부', '현재자녀동거사유_1순위코드', '현재자녀동거사유_2순위코드', '현재자녀동거사유_3순위코드', '현재자녀비동거사유_1순위코드', '현재자녀비동거사유_2순위코드', '현재자녀비동거사유_3순위코드', '향후자녀동거의향여부', '향후희망거처코드', '사회적관계망_가사도움요청대상유무', '사회적관계망_가사도움요청대상인원수', '사회적관계망_자금차입도움요청대상유무', '사회적관계망_자금차입
# ...

# %%
cols_2015 = set(features["2015"])
cols_2017 = set(features["2017"])
cols_2019 = set(features["2019"])
cols_2021 = set(features["2021"])
cols_2023 = set(features["2023"])

# %%
all_items = sorted(cols_2015 | cols_2017 | cols_2019 | cols_2021 | cols_2023)
compare_df = pd.DataFrame({
    "항목명": all_items,
    "2015": [item in cols_2015 for item in all_items],
    "2017": [item in cols_2017 for item in all_items],
    "2019": [item in cols_2019 for item in all_items],
    "2021": [item in cols_2021 for item in all_items],
    "2023": [item in cols_2023 for item in all_items],
})

# 각 행에서 True 개수 세기
compare_df["True_count"] = (compare_df[["2015", "2017", "2019", "2021", "2023"]]).sum(axis=1)

# 출력 옵션: 열 다 보이도록
# 출력 옵션 늘리기
pd.set_option("display.max_rows", None)      # 행 전부 출력
pd.set_option("display.max_columns", None)  # 열 전부 출력
pd.set_option("display.width", None)        # 줄바꿈 없이 한 줄로 출력
pd.set_option("display.max_colwidth", None) # 셀 안 텍스트 길이 제한 해제

print(compare_df)
# Out:
#                                         항목명   2015   2017   2019   2021  \
# 0                                     가구가중값   True   True   True   True
# 1                                    가구소득코드   True   True   True   True
# 2                                    가구원가중값   True   True   True   True
# 3                                     가구원번호   True   True   True   True
# 4                                    가구일련번호   True   True   True   True
# 5                                   가구주관계코드   True   True   True   True
# 6                              개인적인간관계만족도코드  False   True   True   True
# 7                                    거처종류코드   True   True   True   True
# 8                                    계층의식코드   True   True   True   True
# 9                        고용안정성_불안사유_코로나관련여부  False  False  False   True
# 10                                  고용안정성코드   True   True   True   True
# 11                               과거해외여행경험여부   True  False  False  False
# ...

# %%
compare_df.to_csv("항목명_일치여부비교.csv", index=False, encoding="utf-8-sig")

# %%
import re

def normalize_column(col):
    # 한글+숫자+영문만 남기고, 나머지는 제거
    col = re.sub(r"[^가-힣A-Za-z0-9()_]", "", col)
    # 소문자로 변환
    col = col.lower()
    # 맨 뒷 글자 '코드' 제거
    col = re.sub(r"코드$", "", col)
    return col

delete_blink = [normalize_column(c) for c in compare_df["항목명"]]

# %%
compare_df["항목명"]
# Out:
# 0                                       가구가중값
# 1                                      가구소득코드
# 2                                      가구원가중값
# 3                                       가구원번호
# 4                                      가구일련번호
# 5                                     가구주관계코드
# 6                                개인적인간관계만족도코드
# 7                                      거처종류코드
# 8                                      계층의식코드
# 9                          고용안정성_불안사유_코로나관련여부
# 10                                    고용안정성코드
# 11                                 과거해외여행경험여부
# 12                                     교육정도코드
# 13                              국내관광여행_당일여행횟수
# 14                       국내관광여행_미경험사유_코로나관련여부
# 15                        국내관광여행_숙박여행1회평균숙박일수
# 16                              국내관광여행_숙박여행횟수
# 17                                 국내관광여행경험여부
# 18                             근로여건만족도_근로시간코드
# 19                             근로여건만족도_근무환경코드
# ...

# %%
from rapidfuzz import process, fuzz

cols = compare_df["항목명"]
matches = {}
for col in cols:
    match = process.extractOne(col, cols, scorer=fuzz.ratio)
    matches[col] = match

# %%
# 매칭 결과 저장
results = []
for col in compare_df["항목명"]:
    match, score, _ = process.extractOne(col, delete_blink, scorer=fuzz.ratio)
    results.append([col, match, f"{score:.4f}"])

# 데이터프레임으로 변환
match_df = pd.DataFrame(results, columns=["원본컬럼(df1)", "매칭컬럼(df2)", "유사도"])

# CSV로 저장
match_df.to_csv("항목명_매칭결과.csv", index=False, encoding="utf-8-sig")

print("항목명_매칭결과.csv 파일로 저장 완료!")
# Out:
# 항목명_매칭결과.csv 파일로 저장 완료!

# %%
matched_column = {
    "레저시설_스키장이용횟수": "레저시설_스키장스케이트장이용횟수",
    "레저시설이용횟수": "레저시설_이용여부",
    "문화예술스포츠관람_음악연주회횟수": "문화예술스포츠관람_음악연주회콘서트횟수", 
    "분류코드_고용안정성": "분류코드_고용안정성여부",
    "자원봉사활동_재해지역주민돕기시설복구관련횟수": "자원봉사활동_재해지역주민돕기및시설복구관련횟수",
    "자원봉사활동_재해지역주민돕기시설복구관련시간수": "자원봉사활동_재해지역주민돕기및시설복구관련주기",
    "정기기부_현금기부_주기": "정기기부_현금기부주기",
    "정기기부_물품기부_주기": "정기기부_물품기부주기",
    "자원봉사활동_환경보호_연간참여총횟수": "자원봉사활동_환경보전범죄예방관련횟수",
    "자원봉사활동_환경보호_1회평균활동시간수": "자원봉사활동_환경보전범죄예방관련시간수",
    "자원봉사활동_국가지역행사관련시간수": "자원봉사활동_국가및지역행사관련시간수",
    "자원봉사활동_국제협력해외봉사_1회평균활동시간수": "자원봉사활동_국가및지역행사관련시간수",
    "자원봉사활동_국가지역행사관련횟수": "자원봉사활동_국가및지역행사관련횟수",
    "자원봉사활동_국제협력해외봉사_연간참여총횟수": "자원봉사활동_국가및지역행사관련횟수",
    "분류코드_고용안전성": "분류코드_고용안정성여부",
    "기부내용_물품후원단체후원_물품횟수": "기부내용_물품횟수",
    "노후사회적역할기타내용": "노후사회적역할",
    "여가활용불만족사유": "여가활용_불만족사유",
    "노후희망활동_1순위": "노후희망활동"
}

# %%
# 특정 열에서 치환
match_df["매칭컬럼(df2)"] = match_df["매칭컬럼(df2)"].replace(matched_column)
match_df = match_df.drop(columns=["유사도"])
match_df
# Out:
#                                   원본컬럼(df1)  \
# 0                                     가구가중값
# 1                                    가구소득코드
# 2                                    가구원가중값
# 3                                     가구원번호
# 4                                    가구일련번호
# 5                                   가구주관계코드
# 6                              개인적인간관계만족도코드
# 7                                    거처종류코드
# 8                                    계층의식코드
# 9                        고용안정성_불안사유_코로나관련여부
# 10                                  고용안정성코드
# 11                               과거해외여행경험여부
# 12                                   교육정도코드
# 13                            국내관광여행_당일여행횟수
# 14                     국내관광여행_미경험사유_코로나관련여부
# 15                      국내관광여행_숙박여행1회평균숙박일수
# 16                            국내관광여행_숙박여행횟수
# 17                               국내관광여행경험여부
# 18                           근로여건만족도_근로시간코드
# 19                           근로여건만족도_근무환경코드
# ...

# %%
# 매핑 딕셔너리 생성
mapping_dict = dict(zip(match_df["원본컬럼(df1)"], match_df["매칭컬럼(df2)"]))

# 각 데이터프레임 컬럼명 교체 (덮어쓰기 방식)
df_2015 = df_2015.rename(columns=mapping_dict)
df_2017 = df_2017.rename(columns=mapping_dict)
df_2019 = df_2019.rename(columns=mapping_dict)
df_2021 = df_2021.rename(columns=mapping_dict)
df_2023 = df_2023.rename(columns=mapping_dict)

# %%
df_2015['혼인상태'] = df_2015['혼인상태'].replace({3:4, 4:5})
df_2017['혼인상태'] = df_2017['혼인상태'].replace({3:6, 4:3, 5:4, 6:5})
for i in range(1,4):
  df_2021[f'향후추가대상복지서비스_{i}순위'] = df_2021[f'향후추가대상복지서비스_{i}순위'].replace({7:6, 8:9, 9:7, 10:8})
  df_2023[f'향후추가대상복지서비스_{i}순위'] = df_2023[f'향후추가대상복지서비스_{i}순위'].replace({7:6, 8:9, 9:7, 10:8})
df_2021['선호장례방법'] =  df_2021['선호장례방법'].replace({4:5, 5:4})
for i in range(1,4):
  df_2021[f'우선실시장애인복지사업_{i}순위'] = df_2021[f'우선실시장애인복지사업_{i}순위'].replace({3:2, 4:3, 5:4, 6:10, 7:5, 8:6, 9:7, 10:8, 11:9})
  df_2023[f'우선실시장애인복지사업_{i}순위'] = df_2023[f'우선실시장애인복지사업_{i}순위'].replace({3:2, 4:3, 5:4, 6:10, 7:5, 8:6, 9:7, 10:8, 11:9})
for i in range(2,4):
  df_2023[f'노후희망활동_{i}순위'] = df_2023[f'노후희망활동_{i}순위'].replace({2:7, 3:2, 4:3, 5:4, 6:5, 7:6})
df_2021['노후희망활동'] = df_2021['노후희망활동'].replace({2:7, 3:2, 4:3, 5:4, 6:5, 7:6})
for i in range(1,4):
  df_2021[f'직업선택요인_{i}순위'] = df_2021[f'직업선택요인_{i}순위'].replace({7:9, 8:7, 9:8})
for i in range(1,4):
  df_2015[f'현재자녀비동거사유_{i}순위'] = df_2015[f'현재자녀비동거사유_{i}순위'].replace({5:6, 6:5})
  df_2017[f'현재자녀비동거사유_{i}순위'] = df_2017[f'현재자녀비동거사유_{i}순위'].replace({5:6, 6:5})
df_2015['기부여부'] = df_2015['기부여부'].replace({1:1, 2:1, 3:1, 4:0})

# %%
# 연도별 데이터프레임을 딕셔너리에 저장
dfs = {
    "2015": df_2015,
    "2017": df_2017,
    "2019": df_2019,
    "2021": df_2021,
    "2023": df_2023
}

# CSV로 저장 (UTF-8)
for year, df in dfs.items():
    file_name = f"df_{year}.csv"
    df.to_csv(file_name, index=False, encoding="utf-8-sig")
    print(f"{file_name} 저장 완료 ✅")
# Out:
# df_2015.csv 저장 완료 ✅
# df_2017.csv 저장 완료 ✅
# df_2019.csv 저장 완료 ✅
# df_2021.csv 저장 완료 ✅
# df_2023.csv 저장 완료 ✅
